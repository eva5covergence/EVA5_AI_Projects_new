# %%
# !git clone https://github.com/theschoolofai/YoloV3.git
# Out:
# fatal: destination path 'YoloV3' already exists and is not an empty directory.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.6.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
import os
os.chdir("/content/gdrive/My Drive/EVA5/YoloCustom")

# %%
# !ls /content/gdrive/My\ Drive/EVA5/YoloCustom/data/customdata/images/ | wc -l
# Out:
# 3590

# %%
# !ls /content/gdrive/My\ Drive/EVA5/YoloCustom/data/customdata/labels/ | wc -l
# Out:
# 3526

# %%
# !ls
# Out:
#  annotation_tool   output	  runs		    'ubdivisions=1'
#  cfg		   __pycache__	  test_batch0.png    utils
#  data		   README.md	  test.py	     vim.exe.stackdump
#  detect.py	   results.json   ting		     weights
#  models.py	   results.png	  train_batch0.png   YoloV3Sample.ipynb
#  out_out	   results.txt	  train.py

# %%
#!python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 50 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=50, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-23 18:58:30.704056: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (3034 found, 131 missing, 38 empty, 0 duplicate, for 3203 images): 100% 3203/3203 [09:07<00:00,  5.85it/s]
# Caching images (1.8GB): 100% 3203/3203 [10:09<00:00,  5.26it/s]
# ...

# %%
# !python detect.py --source 'data/customdata/Dest_Images' --conf-thres 0.1 --output 'data/customdata/output'
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# image 1/3590 data/customdata/images/01-prince-boots - Copy.jpg: 512x448 2 bootss, Done. (0.044s)
# image 2/3590 data/customdata/images/026f0ffddc.jpg: 384x512 1 masks, Done. (0.037s)
# image 3/3590 data/customdata/images/032620_LS_covid-masks_inline-680.jpg: 320x512 1 hardhats, 1 masks, Done. (0.033s)
# image 4/3590 data/customdata/images/046acbc8e1.jpg: 384x512 1 masks, Done. (0.037s)
# ...

# %%
# !python detect.py --source 'data/customdata/Dest_Images' --conf-thres 0.1 --output 'data/customdata/output'
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='data/customdata/output', save_txt=False, source='data/customdata/Dest_Images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# image 1/1792 data/customdata/Dest_Images/img001.jpg: 384x512 8 hardhats, 8 vests, Done. (0.037s)
# image 2/1792 data/customdata/Dest_Images/img002.jpg: 384x512 8 hardhats, 8 vests, Done. (0.037s)
# image 3/1792 data/customdata/Dest_Images/img003.jpg: 384x512 8 hardhats, 8 vests, Done. (0.037s)
# image 4/1792 data/customdata/Dest_Images/img004.jpg: 384x512 7 hardhats, 9 vests, Done. (0.037s)
# image 5/1792 data/customdata/Dest_Images/img005.jpg: 384x512 8 hardhats, 8 vests, Done. (0.037s)
# ...

# %%
Image(filename='data/customdata/output/img010.jpg', width=600)

# %%
Image(filename='out_out/Aimg_072.jpg', width=600)

# %%
Image(filename='out_out/img003.jpg', width=600)

# %%
Image(filename='out_out/img020.jpg', width=600)
