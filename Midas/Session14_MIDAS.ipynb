# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/My Drive/EVA5/Week14/MiDaSmaster")

# %%
from run import run

# %%
input_path = "/content/drive/My Drive/EVA5/Week14/Images/"
out_path = "/content/drive/My Drive/EVA5/Week14/Output/"
model_path = "/content/drive/My Drive/EVA5/Week14/model-f46da743.pt"

# %%
run(input_path,out_path,model_path)
# Out:
# initialize
# device: cuda
# Loading weights:  /content/drive/My Drive/EVA5/Week14/model-f46da743.pt
# Downloading: "https://github.com/facebookresearch/WSL-Images/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://download.pytorch.org/models/ig_resnext101_32x8-c38310e5.pth" to /root/.cache/torch/hub/checkpoints/ig_resnext101_32x8-c38310e5.pth
# ...
# start processing
#   processing /content/drive/My Drive/EVA5/Week14/Images/K224.jpg (1/3590)
#   processing /content/drive/My Drive/EVA5/Week14/Images/Ky.jpg (2/3590)
#   processing /content/drive/My Drive/EVA5/Week14/Images/K156.jpg (3/3590)
#   processing /content/drive/My Drive/EVA5/Week14/Images/K200.jpg (4/3590)
#   processing /content/drive/My Drive/EVA5/Week14/Images/K234.jpg (5/3590)
#   processing /content/drive/My Drive/EVA5/Week14/Images/K160.jpg (6/3590)
#   processing /content/drive/My Drive/EVA5/Week14/Images/Ka.jpg (7/3590)
#   processing /content/drive/My Drive/EVA5/Week14/Images/Kii.jpg (8/3590)
# ...
