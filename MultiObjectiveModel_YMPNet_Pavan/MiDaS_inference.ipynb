# %%
import os
# !nvidia-smi
# Out:
# Sat Nov  7 12:01:18 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## Midas Depth Estimation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir("/content/drive/My Drive/computer_vision/capstone_project/MiDaS-master/")

# %%
from run import run

# %%
# !ls /content/drive/My\ Drive/computer_vision/capstone_project/capstone_dataset/inputs/ppe_input_images/ | wc -l
# Out:
# 3596

# %%
input = '/content/drive/My Drive/computer_vision/capstone_project/capstone_dataset/inputs/ppe_input_images/'
output = '/content/drive/My Drive/computer_vision/capstone_project/capstone_dataset/ground_truths/depthmap_gt_images/'
model_path = '/content/drive/My Drive/computer_vision/capstone_project/MiDaS-master/model-f46da743.pt'

# %%
run(input_path=input, output_path=output, model_path=model_path)
# Out:
# initialize
# device: cuda
# Loading weights:  /content/drive/My Drive/computer_vision/capstone_project/MiDaS-master/model-f46da743.pt
# Using cache found in /root/.cache/torch/hub/facebookresearch_WSL-Images_master
# start processing
#   processing /content/drive/My Drive/computer_vision/capstone_project/capstone_dataset/inputs/ppe_input_images/majdoor_101.jpg (1/3595)
#   processing /content/drive/My Drive/computer_vision/capstone_project/capstone_dataset/inputs/ppe_input_images/majdoor_7.jpg (2/3595)
#   processing /content/drive/My Drive/computer_vision/capstone_project/capstone_dataset/inputs/ppe_input_images/majdoor_13.jpg (3/3595)
#   processing /content/drive/My Drive/computer_vision/capstone_project/capstone_dataset/inputs/ppe_input_images/majdoor_204.jpg (4/3595)
#   processing /content/drive/My Drive/computer_vision/capstone_project/capstone_dataset/inputs/ppe_input_images/majdoor_212.jpg (5/3595)
# ...

# %%
# !rm /content/drive/My\ Drive/computer_vision/capstone_project/capstone_dataset/inputs/ppe_input_images/camera.txt

# %%
# !ls /content/drive/My\ Drive/computer_vision/capstone_project/capstone_dataset/ground_truths/depthmap_gt_images/ | wc -l
# Out:
# 21250
