# %%
# !nvidia-smi
# Out:
# Sat Nov 28 10:42:11 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import time
import glob
import torch
import os
import PIL

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.7.0+cu101 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', major=7, minor=0, total_memory=16130MB, multi_processor_count=80)

# %%
os.chdir("/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/")

# %%
# !md5sum weights/best.pt
# !md5sum weights/last_best_diwali_2am.pt
# !md5sum weights/last.pt

# %%
# !python detect.py --source './test_images' --conf-thres 0.1 --iou-thres 0.6 --yolo_output './yolo_outs/' --depth_output './depth_outs/' --weights='weights/best.pt'
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, depth_output='./depth_outs/', device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, midas_weights='weights/model-f46da743.pt', names='data/customdata/custom.names', planes_output='planes_output', save_txt=False, source='./test_images', view_img=False, weights='weights/best.pt', yolo_output='./yolo_outs/')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', total_memory=16130MB)
#
# device: cuda:0
# Using cache found in /root/.cache/torch/hub/facebookresearch_WSL-Images_master
# Loaded Model weights successfully
# **** Writing BBOX outs ****
# image 1/1 test_images/PImage47.jpg: 384x512 23 hardhats, 11 vests, 17 masks, 20 bootss, Done. (0.150s)
# Results saved to /content/drive/My Drive/computer_vision/capstone_project/yolo_v3/./yolo_outs/
# **** Writing Depth outs ****
# initialize
# device: cuda:0
# ...

# %%
Image(filename='yolo_outs/PImage47.jpg', width=600)

# %%
Image(filename='depth_outs/PImage47.png', width=600)
