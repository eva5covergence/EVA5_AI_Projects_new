# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir("/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/")

# %%
from torch.utils.data import Dataset, random_split
from PIL import Image
import numpy as np
import torch
import os
import torchvision
import torchvision.transforms as transforms
from tqdm import notebook
import zipfile
import requests
from io import StringIO,BytesIO
import cv2
import pandas as pd
from utils.utils import *
from utils.datasets import *
from utils.parse_config import *
from pathlib import Path
from threading import Thread
import random

# %%
root = '/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/capstone_dataset/'

# %%
train_split = 80
df = pd.read_csv(root+'capstone_metadata.csv')
lst = df.values.tolist()
print(lst[:5])
random.shuffle(lst)
print(lst[:5])
# Out:
# [[0, '/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/capstone_dataset/inputs/ppe_input_images/majdoor_31.jpg', '/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/capstone_dataset/ground_truths/ppe_gt_bbox_labels/majdoor_31.txt', '/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/capstone_dataset/ground_truths/depthmap_gt_images/majdoor_31.png', '/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/capstone_dataset/ground_truths/planar_surface_gt_images/majdoor_31_segmentation_final.png', '/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/capstone_dataset/ground_truths/planar_surface_gt_images/majdoor_31_plane_masks.npy'], [1, '/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/capstone_dataset/inputs/ppe_input_images/majdoor_232.jpg', '/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/da
# ...

# %%
train_len = len(lst)*train_split//100
test_len = len(lst) - train_len
train_lst = lst[:train_len]
# new_lst = list(set(lst)-set(train_lst))
test_lst = lst[train_len:]
print('Trainset length: ',len(train_lst))
print('Testset length: ',len(test_lst))
# Out:
# Trainset length:  2767
# Testset length:  692

# %%
train_path = '/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/train.txt'
print(train_path)
# Out:
# /content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/train.txt

# %%
a = open(train_path, "w")
for data in train_lst:
  # print(data[1])
  a.write(data[1] + os.linesep)

# %%
test_path = '/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/test.txt'
print(test_path)
# Out:
# /content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/test.txt

# %%
b = open(test_path, "w")
for data in test_lst:
  # print(data[1])
  b.write(data[1] + os.linesep)

# %%
import PIL
def write_image_shapes(image_paths_file, target_filepath):
  file_names = open(image_paths_file).readlines()
  with open(target_filepath, 'a') as file_handler:
    for image_path in file_names:
      im = PIL.Image.open(image_path.strip())
      img_width, img_height = [float(dim) for dim in im.size]
      file_handler.write(f'{img_width} {img_height}\n')
  print("Done")

# %%
os.getcwd()
# Out:
# '/content/drive/.shortcut-targets-by-id/1sWX3t22WI1uaZOZwn3b9cypk37vtQun7/EVA5_Capstone/YoloV3master'

# %%
root
# Out:
# '/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/capstone_dataset/'

# %%
write_image_shapes('/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/train.txt',
                   '/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/train.shapes')
# Out:
# Done

# %%
write_image_shapes('/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/test.txt', 
                   '/content/drive/My Drive/computer_vision/capstone_project/yolo_v3/data/customdata/test.shapes')
# Out:
# Done
