# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
project_path = "/content/drive/My Drive/EVA5/Week12/"
os.chdir(project_path)

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from data.base_data_utils import process_bbox_data
from utils.misc_utils import plot_kmeans_clusters_analysis,scatter_plot
from matplotlib import pyplot as plt

# %%
jsonfile_path = project_path+"/data/datasets/ppe_data/Ezhirko/bboxes/PPE_json.json"
images_dir_path = project_path+"/data/datasets/ppe_data/Ezhirko/images/"
final_data = process_bbox_data(jsonfile_path, images_dir_path, data_format='json')
# Out:
# **** Object class counts in all the images ****
#
#  hardhat    198
# boots      184
# vest       182
# mask       135
# Name: object_name, dtype: int64

# %%
final_data.head()
# Out:
#      img_name  img_width  img_height  ...  cy_s_img  bb_width_s_img  bb_height_s_img
# 0  Image1.jpg      797.0       514.0  ...  0.369650        0.352572         0.554475
# 1  Image1.jpg      797.0       514.0  ...  0.252918        0.204517         0.233463
# 2  Image1.jpg      797.0       514.0  ...  0.575875        0.380176         0.766537
# 3  Image1.jpg      797.0       514.0  ...  0.540856        0.946048         0.873541
# 4  Image2.jpg     1000.0       667.0  ...  0.223388        0.228000         0.242879
#
# [5 rows x 14 columns]

# %%
title = "BBox data for kmeans cluster analysis"
x=final_data['bb_width_s_img']
y=final_data['bb_height_s_img']
xlabel = "BBox Width"
ylabel = "BBox Height"
scatter_plot(x,y,title,xlabel,ylabel)

# %%
data = final_data[['bb_width_s_img','bb_height_s_img']]
plot_kmeans_clusters_analysis(data, max_clusters=10)

# %% [markdown]
# Based on above graph through elbow method 3 anchor boxes per grid cell will be good.
